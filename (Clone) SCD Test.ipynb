# %%
# %sql

# TRUNCATE TABLE Final_project.bronze_zone.bronze_chicago

# %%
# %sql

# INSERT INTO final_project.bronze_zone.bronze_chicago (
# Inspection_ID,	DBA_Name,	AKA_Name,	`License_#`,	Facility_Type,	Risk,	Address,	City,	State,	Zip,	Inspection_Date,	Inspection_Type,	Results,	Violations,	Latitude,	Longitude,	Location,	_batch_id,	_source_city,	_ingested_at,	_bronze_loaded_at)
# VALUES (
# "1997266",	"BRENDA'S KIDS CLUB DAYCARE CENTER",	"BRENDA'S KIDS CLUB DAYCARE CENTER Komal",	"2215916",	"Daycare Above and Under 2 Years",	"Risk 1 (High)",	"3552 E 118TH ST",	"CHICAGO",	"IL",	"60617",	"04/10/2026",	"Canvass",	"Pass",	"36. THERMOMETERS PROVIDED & ACCURATE - Comments: NEW REACH IN COOLER THERMOMETERS NEEDED. INSTRUCTED TO REPLACE AND MAINTAIN AT THIS TIME  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: AIR VENT IN REACH IN MILK COOLER IN NEED OF CLEANING TO REMOVE BUILD UP INSTRUCTED TO CORRECT AND MAINTAIN",	"41.68105326817",	"-87.53683432709",	"(41.681053268167084, -87.53683432709336)",	"BATCH_20260409_121408",	"Chicago",	current_timestamp(),	current_timestamp())

# %%
# %sql

select * from final_project.gold_zone.dim_restaurant
-- where dba_name = "SPORTSERVICE SOLDIER FIELD"
where restaurant_id = "3fafd6a11680a5cd09e9b8f577e1c2e8"
